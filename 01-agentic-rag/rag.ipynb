# %%
from rag_helper import RAGBase
from ingest import build_index, load_faq_data

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

openai_client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.getenv("GROQ_API_KEY")   
)

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, openai_client)

# %%
assistant.rag("I just discovered the course, can I still join?")
# Out:
# "Yes, you can still join the course. If you want to receive a certificate, you need to make sure to submit your project while they're still accepting submissions."
